# %% [markdown]
# # Project: Calculator with Exception Handling
# ## Author: Serenity Smith
# ## [Link to Colab](https://colab.research.google.com/drive/1aooTj0_0ccN01HtMsCN8c30e0dBw7DOh?usp=sharing)

# %%
'''
Step 1: Menu of Operations
Create a program that displays a menu with the following operations:

Addition
Subtraction
Multiplication
Division
Exit
The user should select an option by entering a number.

Step 2: Input Validation
Add input validation to ensure the user enters numbers only for the calculations. If the input is invalid, catch the exception and prompt the user again.

Example Output:

plaintext
Copy code
Enter the first number: abc Invalid input! Please enter a valid number.
Step 3: Division with Exception Handling
Handle the following exceptions specifically for the division operation:

ZeroDivisionError: Print a friendly message when dividing by zero.
ValueError: Ensure the inputs are numbers.
Example Output:

plaintext
Copy code
Enter the first number: 10 Enter the second number: 0 Oops! Division by zero is not allowed.
Step 4: Logging Errors (Bonus)
Use the logging module to log errors to a file named error_log.txt whenever an exception occurs.
Example Log Entry:

plaintext
Copy code
ERROR:root:ZeroDivisionError occurred: division by zero.
Step 5: User-Friendly Interface
Enhance the program with the following features:

Clear prompts and instructions.
A try...except...else...finally structure to ensure robustness.
Informative error messages for each exception.
Example Run:

plaintext
Copy code
Welcome to the Error-Free Calculator! Choose an operation: 1. Addition 2. Subtraction 3. Multiplication 4. Division 5. Exit > 4 Enter the first number: 10 Enter the second number: 0 Oops! Division by zero is not allowed. Choose an operation: 5 Goodbye!
Happy debugging and exception handling!

'''

# %%
print("Welcome to the Error-Free Calculator!")

while True:
  choice = int(input("\nWhat math operation would you like to execute? \n1: Addition \n2: Subtraction \n3: Multiplication \n4: Division \n5: Quit \n"))
  if choice == 5:
    print("See you soon!")
    break

  if choice == 1:
    try:
      print("\nYou have selected Addition.")
      num1 = float(input("Enter your first number: "))
      num2 = float(input("Enter your second number: "))
      num3 = (num1 + num2)
    except ValueError:
      print("ValueError: Must be a number!")
    else:
      print(f"{num1} + {num2} = {num3}")

  if choice == 2:
    try:
      print("\nYou have selected Subtraction.")
      num1 = float(input("Enter your first number: "))
      num2 = float(input("Enter your second number: "))
      num3 = (num1 - num2)
    except ValueError:
      print("ValueError: Must be a number!")
    else:
      print(f"{num1} - {num2} = {num3}")

  if choice == 3:
    try:
      print("\nYou have selected Multiplication.")
      num1 = float(input("Enter your first number: "))
      num2 = float(input("Enter your second number: "))
      num3 = (num1 * num2)
    except ValueError:
      print("ValueError: Must be a number!")
    else:
      print(f"{num1} * {num2} = {num3}")

  if choice == 4:
    try:
      print("\nYou have selected Division.")
      num1 = float(input("Enter your first number: "))
      num2 = float(input("Enter your second number: "))
      num3 = (num1 / num2)
    except ValueError:
      print("ValueError: Must be a number!")
    except ZeroDivisionError:
      print("ERROR:root:ZeroDivisionError occurred: division by zero.")
    else:
      print(f"{num1} + {num2} = {num3}")
# Out:
# Welcome to the Error-Free Calculator!
#
# What math operation would you like to execute?
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Quit
# 1
#
# You have selected Addition.
# Enter your first number: 5
# Enter your second number: -10
# 5.0 + -10.0 = -5.0
#
# What math operation would you like to execute?
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Quit
# 1
#
# You have selected Addition.
# Enter your first number: abc
# ValueError: Must be a number!
#
# What math operation would you like to execute?
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Quit
# 2
#
# You have selected Subtraction.
# Enter your first number: 7
# Enter your second number: 7
# 7.0 - 7.0 = 0.0
#
# What math operation would you like to execute?
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Quit
# 2
#
# You have selected Subtraction.
# Enter your first number: 6
# Enter your second number: abc
# ValueError: Must be a number!
#
# What math operation would you like to execute?
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Quit
# 3
#
# You have selected Multiplication.
# Enter your first number: 5
# Enter your second number: 0
# 5.0 * 0.0 = 0.0
#
# What math operation would you like to execute?
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Quit
# 3
#
# You have selected Multiplication.
# Enter your first number: 6
# Enter your second number: abc
# ValueError: Must be a number!
#
# What math operation would you like to execute?
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Quit
# 4
#
# You have selected Division.
# Enter your first number: 4
# Enter your second number: 4
# 4.0 + 4.0 = 1.0
#
# What math operation would you like to execute?
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Quit
# 4
#
# You have selected Division.
# Enter your first number: 6
# Enter your second number: 0
# ERROR:root:ZeroDivisionError occurred: division by zero.
#
# What math operation would you like to execute?
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Quit
# 4
#
# You have selected Division.
# Enter your first number: 6
# Enter your second number: hello
# ValueError: Must be a number!
#
# What math operation would you like to execute?
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Quit
# 5
# See you soon!
