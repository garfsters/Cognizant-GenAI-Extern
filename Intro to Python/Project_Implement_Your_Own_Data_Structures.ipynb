# %% [markdown]
# # Project: Implement Your Own Data Structures
#
# ## Author: Serenity Smith
#
# ## [Link to Colab](https://colab.research.google.com/drive/1sv-dc9UZ01QjhU9fjs-EWSlmL-PYMv7d?usp=sharing)

# %%
'''
Step 1: Create the Inventory

Start with an empty dictionary called inventory.
Each key in the dictionary will represent an item name, and the value will be a tuple containing the quantity and price.
Example:

inventory =
{
"apple": (10, 2.5),
"banana": (20, 1.2)
}
Step 2: Add, Remove, and Update Items

Add functionality to:
Add a new item to the inventory (e.g., "mango": (15, 3.0)).
Remove an item from the inventory.
Update the quantity or price of an existing item.
Step 3: Display the Inventory
Write a loop to display all items in the inventory in a friendly format. For example:

Item: apple, Quantity: 10, Price: $2.5
Item: banana, Quantity: 20, Price: $1.2
Step 4: Bonus - Calculate Total Value
Add a feature to calculate and display the total value of the inventory by multiplying the quantity and price of each item.

Example Run:

Welcome to the Inventory Manager!
Current inventory:
Item: apple, Quantity: 10, Price: $2.5
Item: banana, Quantity: 20, Price: $1.2
Adding a new item: mango
Updated inventory:
Item: apple, Quantity: 10, Price: $2.5
Item: banana, Quantity: 20, Price: $1.2
Item: mango, Quantity: 15, Price: $3.0
Total value of inventory: $90.0
Make sure your program is interactive, user-friendly, and easy to use. Add comments to explain your code for bonus clarity!

'''

# %%
inventory = {}

print("Welcome to the Inventory Manager!")
f = ''

while f != 'Q':
  f = input("\nWhat would you like to do?\n'P' to print items, 'A' to add items, 'R' to remove items, 'U' to update items, 'Q' to quit\n").upper()
  if f == 'Q':
    print("See you later!")
    break

  if f == 'P':
    print("\nInventory List:")
    for i,v in inventory.items():
      print(f"Item: {i}, Quantity:{v[0]}, Price: ${v[1]}")
    x = 0
    for t in inventory.values():
      x += t[0]*t[1]
    print(f"Total inventory value: ${x}")

  if f == 'A':
    item = input("\nWhat would you like to add?")
    quantity = int(input("How much do you have?"))
    price = float(input("How much does one cost?"))
    inventory[item] = (quantity, price)
    print(f"\nAdding item {item} to inventory.")
    print("\nUpdated List:")
    for i,v in inventory.items():
      print(f"Item: {i}, Quantity:{v[0]}, Price: ${v[1]}")
    x = 0
    for t in inventory.values():
      x += t[0]*t[1]
    print(f"Total inventory value: ${x}")


  if f == 'U':
    item = input("\nWhat would you like to update?")
    if inventory.get(item) == None:
      print("That is not on the list, please type 'A' to add it.")
      continue
    quantity = int(input("How much do you have now?"))
    price = float(input("How much does one cost now?"))
    new = {item:(quantity, price)}
    inventory.update(new)
    print(f"\nUpdating item {item} in inventory.")
    print("\nUpdated List:")
    for i,v in inventory.items():
      print(f"Item: {i}, Quantity:{v[0]}, Price: ${v[1]}")
    x = 0
    for t in inventory.values():
      x += t[0]*t[1]
    print(f"Total inventory value: ${x}")

  if f == 'R':
    item = input("\nWhat would you like to remove?")
    if inventory.get(item) == None:
      print("That item is not on the list.")
      continue
    del inventory[item]
    print(f"\nRemoving item {item} from inventory.")
    print(f"\nUpdated List:")
    for i,v in inventory.items():
      print(f"Item: {i}, Quantity:{v[0]}, Price: ${v[1]}")
    x = 0
    for t in inventory.values():
      x += t[0]*t[1]
    print(f"Total inventory value: ${x}")
# Out:
# Welcome to the Inventory Manager!
#
# What would you like to do?
# 'P' to print items, 'A' to add items, 'R' to remove items, 'U' to update items, 'Q' to quit
# p
#
# Inventory List:
# Total inventory value: $0
#
# What would you like to do?
# 'P' to print items, 'A' to add items, 'R' to remove items, 'U' to update items, 'Q' to quit
# a
#
# What would you like to add?mango
# How much do you have?15
# How much does one cost?3.5
#
# Adding item mango to inventory.
#
# Updated List:
# Item: mango, Quantity:15, Price: $3.5
# Total inventory value: $52.5
#
# What would you like to do?
# 'P' to print items, 'A' to add items, 'R' to remove items, 'U' to update items, 'Q' to quit
# u
#
# What would you like to update?banana
# That is not on the list, please type 'A' to add it.
#
# What would you like to do?
# 'P' to print items, 'A' to add items, 'R' to remove items, 'U' to update items, 'Q' to quit
# u
#
# What would you like to update?mango
# How much do you have now?25
# ...
